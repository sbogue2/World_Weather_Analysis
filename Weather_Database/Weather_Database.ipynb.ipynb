# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
       
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | honggang
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | paredon
# Processing Record 8 of Set 1 | broome
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | taft
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | progreso
# Processing Record 13 of Set 1 | lasa
# Processing Record 14 of Set 1 | berbera
# Processing Record 15 of Set 1 | palmer
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | san jeronimo
# Processing Record 18 of Set 1 | lazarev
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | egvekinot
# Processing Record 24 of Set 1 | hobyo
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | sitka
# Processing Record 28 of Set 1 | camopi
# Processing Record 29 of Set 1 | etah
# Processing Record 30 of Set 1 | fushun
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | port hardy
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | ostrovnoy
# Processing Record 35 of Set 1 | port lincoln
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | inongo
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | katsuura
# Processing Record 47 of Set 1 | klaksvik
# Processing Record 48 of Set 1 | kochki
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 2 | kalmunai
# Processing Record 2 of Set 2 | beruwala
# Processing Record 3 of Set 2 | caravelas
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | abu samrah
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | kristiinankaupunki
# Processing Record 9 of Set 2 | baillif
# Processing Record 10 of Set 2 | frontera
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | balikpapan
# Processing Record 13 of Set 2 | geraldton
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | ballitoville
# Processing Record 16 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 2 | plymouth
# Processing Record 18 of Set 2 | san buenaventura
# Processing Record 19 of Set 2 | gua musang
# Processing Record 20 of Set 2 | svetlogorsk
# Processing Record 21 of Set 2 | dunedin
# Processing Record 22 of Set 2 | kahului
# Processing Record 23 of Set 2 | huaihua
# Processing Record 24 of Set 2 | gorin
# Processing Record 25 of Set 2 | kenai
# Processing Record 26 of Set 2 | byron bay
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | gat
# Processing Record 29 of Set 2 | cartagena del chaira
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | yining
# Processing Record 32 of Set 2 | rawson
# Processing Record 33 of Set 2 | acapulco
# Processing Record 34 of Set 2 | fairbanks
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | meulaboh
# Processing Record 37 of Set 2 | yaan
# Processing Record 38 of Set 2 | suluq
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 2 | laguna
# Processing Record 43 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 2 | port macquarie
# Processing Record 45 of Set 2 | goderich
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | menongue
# Processing Record 49 of Set 2 | lata
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | codrington
# Processing Record 3 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | bethel
# Processing Record 6 of Set 3 | tuatapere
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | amurzet
# Processing Record 10 of Set 3 | naze
# Processing Record 11 of Set 3 | villamontes
# Processing Record 12 of Set 3 | praia da vitoria
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | miandrivazo
# Processing Record 16 of Set 3 | srednekolymsk
# Processing Record 17 of Set 3 | faya
# Processing Record 18 of Set 3 | oyama
# Processing Record 19 of Set 3 | likasi
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | hofn
# Processing Record 22 of Set 3 | xining
# Processing Record 23 of Set 3 | padang
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | baykit
# Processing Record 26 of Set 3 | champua
# Processing Record 27 of Set 3 | przhevalskoye
# Processing Record 28 of Set 3 | nanortalik
# Processing Record 29 of Set 3 | kloulklubed
# Processing Record 30 of Set 3 | kvarkeno
# Processing Record 31 of Set 3 | munchberg
# Processing Record 32 of Set 3 | gigmoto
# Processing Record 33 of Set 3 | xiaoweizhai
# Processing Record 34 of Set 3 | inhambane
# Processing Record 35 of Set 3 | salalah
# Processing Record 36 of Set 3 | vardo
# Processing Record 37 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | grindavik
# Processing Record 39 of Set 3 | elko
# Processing Record 40 of Set 3 | kaitangata
# Processing Record 41 of Set 3 | pangkalanbuun
# Processing Record 42 of Set 3 | caluquembe
# Processing Record 43 of Set 3 | christchurch
# Processing Record 44 of Set 3 | imeni poliny osipenko
# Processing Record 45 of Set 3 | saint-pierre
# Processing Record 46 of Set 3 | talnakh
# Processing Record 47 of Set 3 | rodos
# Processing Record 48 of Set 3 | gamba
# Processing Record 49 of Set 3 | luzhou
# Processing Record 50 of Set 3 | auki
# Processing Record 1 of Set 4 | okhotsk
# Processing Record 2 of Set 4 | souillac
# Processing Record 3 of Set 4 | ruangwa
# Processing Record 4 of Set 4 | bengkulu
# Processing Record 5 of Set 4 | zanjan
# Processing Record 6 of Set 4 | muskogee
# Processing Record 7 of Set 4 | kavieng
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | pahuatlan
# City not found. Skipping...
# Processing Record 10 of Set 4 | ahipara
# Processing Record 11 of Set 4 | lavrentiya
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | lebanon
# Processing Record 14 of Set 4 | olafsvik
# Processing Record 15 of Set 4 | linchuan
# City not found. Skipping...
# Processing Record 16 of Set 4 | rockland
# Processing Record 17 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 4 | khor
# Processing Record 19 of Set 4 | sao joao da barra
# Processing Record 20 of Set 4 | badarganj
# Processing Record 21 of Set 4 | clyde river
# Processing Record 22 of Set 4 | samarai
# Processing Record 23 of Set 4 | washougal
# Processing Record 24 of Set 4 | georgetown
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | victoria
# Processing Record 27 of Set 4 | borogontsy
# Processing Record 28 of Set 4 | oranjemund
# Processing Record 29 of Set 4 | saint george
# Processing Record 30 of Set 4 | cape town
# Processing Record 31 of Set 4 | sandwick
# Processing Record 32 of Set 4 | goteborg
# City not found. Skipping...
# Processing Record 33 of Set 4 | jamu mare
# Processing Record 34 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 4 | kiama
# Processing Record 36 of Set 4 | shingu
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | norman wells
# Processing Record 39 of Set 4 | belaya gora
# Processing Record 40 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 4 | mar del plata
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | midland
# Processing Record 44 of Set 4 | seymchan
# Processing Record 45 of Set 4 | mamakan
# Processing Record 46 of Set 4 | castro
# Processing Record 47 of Set 4 | kondopoga
# Processing Record 48 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 4 | millinocket
# Processing Record 50 of Set 4 | grand gaube
# Processing Record 1 of Set 5 | ondangwa
# Processing Record 2 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 5 | thai binh
# Processing Record 4 of Set 5 | yar-sale
# Processing Record 5 of Set 5 | udachnyy
# Processing Record 6 of Set 5 | kosh-agach
# Processing Record 7 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 5 | chumikan
# Processing Record 9 of Set 5 | gandai
# Processing Record 10 of Set 5 | syracuse
# Processing Record 11 of Set 5 | goroka
# Processing Record 12 of Set 5 | sioux lookout
# Processing Record 13 of Set 5 | ilulissat
# Processing Record 14 of Set 5 | suicheng
# Processing Record 15 of Set 5 | bousso
# Processing Record 16 of Set 5 | korem
# Processing Record 17 of Set 5 | sechura
# Processing Record 18 of Set 5 | masterton
# Processing Record 19 of Set 5 | nipawin
# Processing Record 20 of Set 5 | kerema
# Processing Record 21 of Set 5 | ixtapa
# Processing Record 22 of Set 5 | hami
# Processing Record 23 of Set 5 | thompson
# Processing Record 24 of Set 5 | almenevo
# City not found. Skipping...
# Processing Record 25 of Set 5 | avera
# Processing Record 26 of Set 5 | isangel
# Processing Record 27 of Set 5 | ondjiva
# Processing Record 28 of Set 5 | nago
# Processing Record 29 of Set 5 | carupano
# Processing Record 30 of Set 5 | amberieu-en-bugey
# Processing Record 31 of Set 5 | ballangen
# Processing Record 32 of Set 5 | majalgaon
# Processing Record 33 of Set 5 | kayerkan
# Processing Record 34 of Set 5 | margate
# Processing Record 35 of Set 5 | north bend
# Processing Record 36 of Set 5 | ourossogui
# Processing Record 37 of Set 5 | alferrarede
# Processing Record 38 of Set 5 | sawakin
# Processing Record 39 of Set 5 | chapais
# Processing Record 40 of Set 5 | kirensk
# Processing Record 41 of Set 5 | ekibastuz
# Processing Record 42 of Set 5 | lienz
# Processing Record 43 of Set 5 | broken hill
# Processing Record 44 of Set 5 | korla
# Processing Record 45 of Set 5 | cherskiy
# Processing Record 46 of Set 5 | bibai
# Processing Record 47 of Set 5 | la macarena
# Processing Record 48 of Set 5 | robertsport
# Processing Record 49 of Set 5 | carnarvon
# Processing Record 50 of Set 5 | qaqortoq
# Processing Record 1 of Set 6 | kiunga
# Processing Record 2 of Set 6 | polunochnoye
# Processing Record 3 of Set 6 | dwarka
# Processing Record 4 of Set 6 | kaka
# Processing Record 5 of Set 6 | kibala
# Processing Record 6 of Set 6 | axim
# Processing Record 7 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 6 | benguela
# Processing Record 9 of Set 6 | lorengau
# Processing Record 10 of Set 6 | los llanos de aridane
# Processing Record 11 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 6 | manzhouli
# Processing Record 13 of Set 6 | bulawayo
# Processing Record 14 of Set 6 | kapchorwa
# Processing Record 15 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 6 | haines junction
# Processing Record 17 of Set 6 | san ramon
# Processing Record 18 of Set 6 | puerto del rosario
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | hambantota
# Processing Record 21 of Set 6 | bakel
# Processing Record 22 of Set 6 | naldurg
# Processing Record 23 of Set 6 | port hedland
# Processing Record 24 of Set 6 | casablanca
# Processing Record 25 of Set 6 | churapcha
# Processing Record 26 of Set 6 | pisco
# Processing Record 27 of Set 6 | parli
# Processing Record 28 of Set 6 | tkibuli
# Processing Record 29 of Set 6 | kalach-na-donu
# Processing Record 30 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 6 | crixas
# Processing Record 32 of Set 6 | moron
# Processing Record 33 of Set 6 | surt
# Processing Record 34 of Set 6 | thinadhoo
# Processing Record 35 of Set 6 | riyadh
# Processing Record 36 of Set 6 | saint-augustin
# Processing Record 37 of Set 6 | iqaluit
# Processing Record 38 of Set 6 | southbridge
# Processing Record 39 of Set 6 | kamaishi
# Processing Record 40 of Set 6 | mongo
# Processing Record 41 of Set 6 | conde
# Processing Record 42 of Set 6 | port-gentil
# Processing Record 43 of Set 6 | ostrogozhsk
# Processing Record 44 of Set 6 | laurinburg
# Processing Record 45 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 6 | ternate
# Processing Record 47 of Set 6 | alofi
# Processing Record 48 of Set 6 | leningradskiy
# Processing Record 49 of Set 6 | alice springs
# Processing Record 50 of Set 6 | gondanglegi
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | balkhash
# Processing Record 3 of Set 7 | hulan
# Processing Record 4 of Set 7 | tiznit
# Processing Record 5 of Set 7 | carutapera
# Processing Record 6 of Set 7 | wenatchee
# Processing Record 7 of Set 7 | tilichiki
# Processing Record 8 of Set 7 | narsaq
# Processing Record 9 of Set 7 | tombouctou
# Processing Record 10 of Set 7 | kangaba
# Processing Record 11 of Set 7 | raudeberg
# Processing Record 12 of Set 7 | vila velha
# Processing Record 13 of Set 7 | stabat
# Processing Record 14 of Set 7 | les cayes
# Processing Record 15 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 7 | krasnoselkup
# Processing Record 17 of Set 7 | hay river
# Processing Record 18 of Set 7 | sangar
# Processing Record 19 of Set 7 | sur
# Processing Record 20 of Set 7 | tiassale
# Processing Record 21 of Set 7 | port alberni
# Processing Record 22 of Set 7 | kudahuvadhoo
# Processing Record 23 of Set 7 | fukue
# Processing Record 24 of Set 7 | nyurba
# Processing Record 25 of Set 7 | krabi
# Processing Record 26 of Set 7 | hamilton
# Processing Record 27 of Set 7 | daru
# Processing Record 28 of Set 7 | kirakira
# Processing Record 29 of Set 7 | benghazi
# Processing Record 30 of Set 7 | beyneu
# Processing Record 31 of Set 7 | dhidhdhoo
# Processing Record 32 of Set 7 | zhuanghe
# Processing Record 33 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 7 | graham
# Processing Record 35 of Set 7 | bilma
# Processing Record 36 of Set 7 | georgiyevka
# Processing Record 37 of Set 7 | faanui
# Processing Record 38 of Set 7 | zeya
# Processing Record 39 of Set 7 | khatanga
# Processing Record 40 of Set 7 | pringsewu
# Processing Record 41 of Set 7 | cabo san lucas
# Processing Record 42 of Set 7 | vytegra
# Processing Record 43 of Set 7 | henties bay
# Processing Record 44 of Set 7 | itarema
# Processing Record 45 of Set 7 | chuy
# Processing Record 46 of Set 7 | mayo
# Processing Record 47 of Set 7 | berlevag
# Processing Record 48 of Set 7 | port elizabeth
# Processing Record 49 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 7 | maragogi
# Processing Record 1 of Set 8 | vanimo
# Processing Record 2 of Set 8 | flin flon
# Processing Record 3 of Set 8 | nome
# Processing Record 4 of Set 8 | wasilla
# Processing Record 5 of Set 8 | lebu
# Processing Record 6 of Set 8 | parras
# City not found. Skipping...
# Processing Record 7 of Set 8 | sulangan
# Processing Record 8 of Set 8 | karasburg
# Processing Record 9 of Set 8 | taltal
# Processing Record 10 of Set 8 | nouakchott
# Processing Record 11 of Set 8 | antsohihy
# Processing Record 12 of Set 8 | anzio
# Processing Record 13 of Set 8 | provideniya
# Processing Record 14 of Set 8 | guapo
# Processing Record 15 of Set 8 | victor harbor
# Processing Record 16 of Set 8 | mirabela
# Processing Record 17 of Set 8 | aykhal
# Processing Record 18 of Set 8 | araxa
# Processing Record 19 of Set 8 | sakakah
# Processing Record 20 of Set 8 | merauke
# Processing Record 21 of Set 8 | barcelos
# Processing Record 22 of Set 8 | fortuna
# Processing Record 23 of Set 8 | tanjong sepat
# City not found. Skipping...
# Processing Record 24 of Set 8 | vestmannaeyjar
# Processing Record 25 of Set 8 | porto velho
# Processing Record 26 of Set 8 | mbumi
# Processing Record 27 of Set 8 | kelvington
# Processing Record 28 of Set 8 | ussel
# Processing Record 29 of Set 8 | acarigua
# Processing Record 30 of Set 8 | vao
# Processing Record 31 of Set 8 | delijan
# Processing Record 32 of Set 8 | keflavik
# Processing Record 33 of Set 8 | medicine hat
# Processing Record 34 of Set 8 | jizan
# Processing Record 35 of Set 8 | basse-pointe
# Processing Record 36 of Set 8 | nakhon thai
# Processing Record 37 of Set 8 | namibe
# Processing Record 38 of Set 8 | nanuque
# Processing Record 39 of Set 8 | oktyabrskoye
# Processing Record 40 of Set 8 | ventspils
# Processing Record 41 of Set 8 | tual
# Processing Record 42 of Set 8 | bubaque
# Processing Record 43 of Set 8 | hervey bay
# Processing Record 44 of Set 8 | saurimo
# Processing Record 45 of Set 8 | esmeraldas
# Processing Record 46 of Set 8 | erzin
# Processing Record 47 of Set 8 | zilair
# Processing Record 48 of Set 8 | moranbah
# Processing Record 49 of Set 8 | la ronge
# Processing Record 50 of Set 8 | astana
# Processing Record 1 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 2 of Set 9 | ust-kuyga
# Processing Record 3 of Set 9 | sola
# Processing Record 4 of Set 9 | saint joseph
# Processing Record 5 of Set 9 | torbay
# Processing Record 6 of Set 9 | dingle
# Processing Record 7 of Set 9 | tyulgan
# Processing Record 8 of Set 9 | touros
# Processing Record 9 of Set 9 | dum duma
# Processing Record 10 of Set 9 | sao filipe
# Processing Record 11 of Set 9 | cayenne
# Processing Record 12 of Set 9 | prince rupert
# Processing Record 13 of Set 9 | kutum
# Processing Record 14 of Set 9 | moissala
# Processing Record 15 of Set 9 | urumqi
# Processing Record 16 of Set 9 | sistranda
# Processing Record 17 of Set 9 | pouembout
# Processing Record 18 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 9 | yumaguzino
# Processing Record 20 of Set 9 | yulara
# Processing Record 21 of Set 9 | hashtrud
# Processing Record 22 of Set 9 | tortoli
# Processing Record 23 of Set 9 | tucurui
# Processing Record 24 of Set 9 | klyuchi
# Processing Record 25 of Set 9 | dhanera
# Processing Record 26 of Set 9 | batagay
# Processing Record 27 of Set 9 | dharchula
# Processing Record 28 of Set 9 | nova vicosa
# Processing Record 29 of Set 9 | magnolia
# Processing Record 30 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 9 | nhulunbuy
# Processing Record 32 of Set 9 | eureka
# Processing Record 33 of Set 9 | ca mau
# Processing Record 34 of Set 9 | fare
# Processing Record 35 of Set 9 | belmonte
# Processing Record 36 of Set 9 | caudry
# Processing Record 37 of Set 9 | flagstaff
# Processing Record 38 of Set 9 | balcani
# Processing Record 39 of Set 9 | beisfjord
# Processing Record 40 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 9 | iracoubo
# Processing Record 42 of Set 9 | husavik
# Processing Record 43 of Set 9 | san carlos del zulia
# Processing Record 44 of Set 9 | muros
# Processing Record 45 of Set 9 | seeboden
# Processing Record 46 of Set 9 | carlsbad
# Processing Record 47 of Set 9 | xiongzhou
# Processing Record 48 of Set 9 | kijang
# Processing Record 49 of Set 9 | kidal
# Processing Record 50 of Set 9 | hue
# Processing Record 1 of Set 10 | whitehorse
# Processing Record 2 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 10 | kurchum
# Processing Record 4 of Set 10 | coquimbo
# Processing Record 5 of Set 10 | markova
# Processing Record 6 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 10 | russell
# Processing Record 8 of Set 10 | cap malheureux
# Processing Record 9 of Set 10 | hualmay
# Processing Record 10 of Set 10 | trojes
# Processing Record 11 of Set 10 | awbari
# Processing Record 12 of Set 10 | severo-kurilsk
# Processing Record 13 of Set 10 | carnduff
# Processing Record 14 of Set 10 | mkushi
# Processing Record 15 of Set 10 | novobiryusinskiy
# Processing Record 16 of Set 10 | curuca
# Processing Record 17 of Set 10 | buala
# Processing Record 18 of Set 10 | catamarca
# Processing Record 19 of Set 10 | tirumala
# Processing Record 20 of Set 10 | omboue
# Processing Record 21 of Set 10 | hauterive
# Processing Record 22 of Set 10 | ashdod
# Processing Record 23 of Set 10 | aklavik
# Processing Record 24 of Set 10 | deder
# Processing Record 25 of Set 10 | funehiki
# Processing Record 26 of Set 10 | bulaevo
# Processing Record 27 of Set 10 | neiafu
# Processing Record 28 of Set 10 | makakilo city
# Processing Record 29 of Set 10 | wattegama
# Processing Record 30 of Set 10 | tezu
# Processing Record 31 of Set 10 | tabuk
# Processing Record 32 of Set 10 | ketchikan
# Processing Record 33 of Set 10 | chicama
# Processing Record 34 of Set 10 | northam
# Processing Record 35 of Set 10 | pacifica
# Processing Record 36 of Set 10 | san julian
# Processing Record 37 of Set 10 | saldanha
# Processing Record 38 of Set 10 | comodoro rivadavia
# Processing Record 39 of Set 10 | ahuimanu
# Processing Record 40 of Set 10 | kruisfontein
# Processing Record 41 of Set 10 | freeport
# Processing Record 42 of Set 10 | salinas
# Processing Record 43 of Set 10 | jumla
# Processing Record 44 of Set 10 | leh
# Processing Record 45 of Set 10 | rio cuarto
# Processing Record 46 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 10 | antofagasta
# Processing Record 48 of Set 10 | sherlovaya gora
# Processing Record 49 of Set 10 | kismayo
# Processing Record 50 of Set 10 | mikhaylovka
# Processing Record 1 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 11 | jubayl
# City not found. Skipping...
# Processing Record 3 of Set 11 | borovoy
# Processing Record 4 of Set 11 | sobolevo
# Processing Record 5 of Set 11 | mocuba
# Processing Record 6 of Set 11 | labuhan
# Processing Record 7 of Set 11 | bucerias
# Processing Record 8 of Set 11 | college
# Processing Record 9 of Set 11 | banda aceh
# Processing Record 10 of Set 11 | tautira
# Processing Record 11 of Set 11 | umm jarr
# City not found. Skipping...
# Processing Record 12 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 13 of Set 11 | vila franca do campo
# Processing Record 14 of Set 11 | qasigiannguit
# Processing Record 15 of Set 11 | brae
# Processing Record 16 of Set 11 | fuyu
# Processing Record 17 of Set 11 | alihe
# Processing Record 18 of Set 11 | aripuana
# Processing Record 19 of Set 11 | harper
# Processing Record 20 of Set 11 | teneguiban
# City not found. Skipping...
# Processing Record 21 of Set 11 | khani
# Processing Record 22 of Set 11 | locri
# Processing Record 23 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 11 | nelson bay
# Processing Record 25 of Set 11 | gilazi
# City not found. Skipping...
# Processing Record 26 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 11 | uglovskoye
# Processing Record 28 of Set 11 | impfondo
# Processing Record 29 of Set 11 | chapeco
# Processing Record 30 of Set 11 | eskilstuna
# Processing Record 31 of Set 11 | bonthe
# Processing Record 32 of Set 11 | seoul
# Processing Record 33 of Set 11 | tieli
# Processing Record 34 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 11 | araouane
# Processing Record 36 of Set 11 | medyn
# Processing Record 37 of Set 11 | taree
# Processing Record 38 of Set 11 | ericeira
# Processing Record 39 of Set 11 | tunceli
# Processing Record 40 of Set 11 | synya
# Processing Record 41 of Set 11 | taoudenni
# Processing Record 42 of Set 11 | nouadhibou
# Processing Record 43 of Set 11 | atar
# Processing Record 44 of Set 11 | kropotkin
# Processing Record 45 of Set 11 | cangucu
# Processing Record 46 of Set 11 | kindu
# Processing Record 47 of Set 11 | lawrenceburg
# Processing Record 48 of Set 11 | susanville
# Processing Record 49 of Set 11 | katobu
# Processing Record 50 of Set 11 | fenoarivo
# Processing Record 1 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 12 | amuntai
# Processing Record 3 of Set 12 | wronki
# Processing Record 4 of Set 12 | zubova polyana
# Processing Record 5 of Set 12 | paamiut
# Processing Record 6 of Set 12 | truro
# Processing Record 7 of Set 12 | petukhovo
# Processing Record 8 of Set 12 | schmelz
# Processing Record 9 of Set 12 | liberia
# Processing Record 10 of Set 12 | preobrazheniye
# Processing Record 11 of Set 12 | pedasi
# Processing Record 12 of Set 12 | goure
# Processing Record 13 of Set 12 | pokhara
# Processing Record 14 of Set 12 | zhongshu
# Processing Record 15 of Set 12 | gerede
# Processing Record 16 of Set 12 | visnes
# Processing Record 17 of Set 12 | karratha
# Processing Record 18 of Set 12 | cockburn town
# Processing Record 19 of Set 12 | puerto cabezas
# Processing Record 20 of Set 12 | san cristobal
# Processing Record 21 of Set 12 | oktyabrskiy
# Processing Record 22 of Set 12 | neryungri
# Processing Record 23 of Set 12 | del pilar
# Processing Record 24 of Set 12 | garwa
# Processing Record 25 of Set 12 | nara
# Processing Record 26 of Set 12 | san juan
# Processing Record 27 of Set 12 | thaton
# Processing Record 28 of Set 12 | bouca
# Processing Record 29 of Set 12 | novaya ladoga
# Processing Record 30 of Set 12 | longyearbyen
# Processing Record 31 of Set 12 | tabou
# Processing Record 32 of Set 12 | vagay
# Processing Record 33 of Set 12 | san bartolome de tirajana
# Processing Record 34 of Set 12 | portland
# Processing Record 35 of Set 12 | spokane
# Processing Record 36 of Set 12 | vila do maio
# Processing Record 37 of Set 12 | forbes
# Processing Record 38 of Set 12 | flinders
# Processing Record 39 of Set 12 | vostok
# Processing Record 40 of Set 12 | pacific grove
# Processing Record 41 of Set 12 | mogadishu
# Processing Record 42 of Set 12 | rocha
# Processing Record 43 of Set 12 | west wendover
# Processing Record 44 of Set 12 | mananjary
# Processing Record 45 of Set 12 | veraval
# Processing Record 46 of Set 12 | bela
# Processing Record 47 of Set 12 | mount gambier
# Processing Record 48 of Set 12 | nuuk
# Processing Record 49 of Set 12 | santa cruz
# Processing Record 50 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 13 | lagos
# Processing Record 2 of Set 13 | jagdalpur
# Processing Record 3 of Set 13 | santa rosa
# Processing Record 4 of Set 13 | bathsheba
# Processing Record 5 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 6 of Set 13 | santona
# Processing Record 7 of Set 13 | camanducaia
# Processing Record 8 of Set 13 | boshkengash
# Processing Record 9 of Set 13 | aksu
# Processing Record 10 of Set 13 | soyo
# Processing Record 11 of Set 13 | concepcion
# Processing Record 12 of Set 13 | quatre cocos
# Processing Record 13 of Set 13 | noumea
# Processing Record 14 of Set 13 | luanda
# Processing Record 15 of Set 13 | yankton
# Processing Record 16 of Set 13 | luganville
# Processing Record 17 of Set 13 | teknaf
# Processing Record 18 of Set 13 | coihaique
# Processing Record 19 of Set 13 | wajima
# Processing Record 20 of Set 13 | unidad
# Processing Record 21 of Set 13 | matara
# Processing Record 22 of Set 13 | nador
# Processing Record 23 of Set 13 | santo domingo
# Processing Record 24 of Set 13 | xiongshi
# City not found. Skipping...
# Processing Record 25 of Set 13 | acajutla
# Processing Record 26 of Set 13 | kamuli
# Processing Record 27 of Set 13 | santa maria del oro
# Processing Record 28 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 29 of Set 13 | ponta delgada
# Processing Record 30 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 13 | saint-jean-port-joli
# Processing Record 32 of Set 13 | marzuq
# Processing Record 33 of Set 13 | anloga
# Processing Record 34 of Set 13 | dongsheng
# Processing Record 35 of Set 13 | adwa
# Processing Record 36 of Set 13 | skovde
# City not found. Skipping...
# Processing Record 37 of Set 13 | jomalig
# City not found. Skipping...
# Processing Record 38 of Set 13 | saint-joseph
# Processing Record 39 of Set 13 | tateyama
# Processing Record 40 of Set 13 | skelleftea
# Processing Record 41 of Set 13 | dangriga
# Processing Record 42 of Set 13 | cody
# Processing Record 43 of Set 13 | alice
# Processing Record 44 of Set 13 | jati
# Processing Record 45 of Set 13 | coolum beach
# Processing Record 46 of Set 13 | makat
# Processing Record 47 of Set 13 | kununurra
# Processing Record 48 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 13 | mandalgovi
# Processing Record 50 of Set 13 | port-cartier
# Processing Record 1 of Set 14 | mwinilunga
# Processing Record 2 of Set 14 | burica
# City not found. Skipping...
# Processing Record 3 of Set 14 | jiancheng
# Processing Record 4 of Set 14 | cervo
# Processing Record 5 of Set 14 | saint anthony
# Processing Record 6 of Set 14 | puerto narino
# Processing Record 7 of Set 14 | kasane
# Processing Record 8 of Set 14 | mmabatho
# Processing Record 9 of Set 14 | dulian
# Processing Record 10 of Set 14 | gurupa
# Processing Record 11 of Set 14 | buraydah
# Processing Record 12 of Set 14 | ugoofaaru
# Processing Record 13 of Set 14 | rovaniemi
# Processing Record 14 of Set 14 | ulaangom
# Processing Record 15 of Set 14 | chernyakhiv
# Processing Record 16 of Set 14 | douentza
# Processing Record 17 of Set 14 | yefira
# City not found. Skipping...
# Processing Record 18 of Set 14 | atyrau
# Processing Record 19 of Set 14 | parfenyevo
# Processing Record 20 of Set 14 | abapo
# Processing Record 21 of Set 14 | anshun
# Processing Record 22 of Set 14 | ostersund
# Processing Record 23 of Set 14 | baruun-urt
# Processing Record 24 of Set 14 | caiaponia
# Processing Record 25 of Set 14 | tsabong
# Processing Record 26 of Set 14 | izhma
# Processing Record 27 of Set 14 | lagoa
# Processing Record 28 of Set 14 | nishiwaki
# Processing Record 29 of Set 14 | nuevo progreso
# Processing Record 30 of Set 14 | eyl
# Processing Record 31 of Set 14 | nantucket
# Processing Record 32 of Set 14 | gornopravdinsk
# Processing Record 33 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 34 of Set 14 | vega de alatorre
# Processing Record 35 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 14 | bac lieu
# Processing Record 37 of Set 14 | omsukchan
# Processing Record 38 of Set 14 | purpe
# Processing Record 39 of Set 14 | phan thiet
# Processing Record 40 of Set 14 | owando
# Processing Record 41 of Set 14 | manta
# Processing Record 42 of Set 14 | elizabeth city
# Processing Record 43 of Set 14 | ornskoldsvik
# Processing Record 44 of Set 14 | chernyshevsk
# Processing Record 45 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 46 of Set 14 | polson
# Processing Record 47 of Set 14 | rock sound
# Processing Record 48 of Set 14 | chaumont
# Processing Record 49 of Set 14 | kalemie
# Processing Record 50 of Set 14 | puerto carreno
# Processing Record 1 of Set 15 | amapa
# Processing Record 2 of Set 15 | bilibino
# Processing Record 3 of Set 15 | nyergesujfalu
# Processing Record 4 of Set 15 | tahta
# Processing Record 5 of Set 15 | valdivia
# Processing Record 6 of Set 15 | swabi
# Processing Record 7 of Set 15 | kayasula
# Processing Record 8 of Set 15 | marquette
# Processing Record 9 of Set 15 | kolokani
# Processing Record 10 of Set 15 | gustrow
# Processing Record 11 of Set 15 | sept-iles
# Processing Record 12 of Set 15 | talcahuano
# Processing Record 13 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 15 | lidkoping
# Processing Record 15 of Set 15 | pudem
# Processing Record 16 of Set 15 | arroyo
# Processing Record 17 of Set 15 | kagalnitskaya
# Processing Record 18 of Set 15 | kungurtug
# Processing Record 19 of Set 15 | iskateley
# Processing Record 20 of Set 15 | pasighat
# Processing Record 21 of Set 15 | porbandar
# Processing Record 22 of Set 15 | bellmead
# Processing Record 23 of Set 15 | pitsunda
# Processing Record 24 of Set 15 | kralendijk
# Processing Record 25 of Set 15 | khammam
# Processing Record 26 of Set 15 | poum
# Processing Record 27 of Set 15 | saumur
# Processing Record 28 of Set 15 | gurupi
# Processing Record 29 of Set 15 | erenhot
# Processing Record 30 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 31 of Set 15 | tartagal
# Processing Record 32 of Set 15 | koslan
# Processing Record 33 of Set 15 | komsomolskiy
# Processing Record 34 of Set 15 | tres passos
# Processing Record 35 of Set 15 | tommot
# Processing Record 36 of Set 15 | te anau
# Processing Record 37 of Set 15 | kizhinga
# Processing Record 38 of Set 15 | show low
# Processing Record 39 of Set 15 | rundu
# Processing Record 40 of Set 15 | oussouye
# Processing Record 41 of Set 15 | mitsamiouli
# Processing Record 42 of Set 15 | lemesos
# City not found. Skipping...
# Processing Record 43 of Set 15 | pangai
# Processing Record 44 of Set 15 | karasjok
# Processing Record 45 of Set 15 | weligama
# Processing Record 46 of Set 15 | harwich
# Processing Record 47 of Set 15 | biak
# Processing Record 48 of Set 15 | lufilufi
# Processing Record 49 of Set 15 | linxia
# Processing Record 50 of Set 15 | chipinge
# Processing Record 1 of Set 16 | las vegas
# Processing Record 2 of Set 16 | asau
# Processing Record 3 of Set 16 | raga
# Processing Record 4 of Set 16 | jalu
# Processing Record 5 of Set 16 | trincomalee
# Processing Record 6 of Set 16 | mahibadhoo
# Processing Record 7 of Set 16 | umea
# Processing Record 8 of Set 16 | tazovskiy
# Processing Record 9 of Set 16 | oga
# Processing Record 10 of Set 16 | walvis bay
# Processing Record 11 of Set 16 | baisha
# Processing Record 12 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 16 | slobodskoy
# Processing Record 14 of Set 16 | vokhtoga
# Processing Record 15 of Set 16 | teshie
# Processing Record 16 of Set 16 | hiranagar
# Processing Record 17 of Set 16 | palana
# Processing Record 18 of Set 16 | illescas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton -33.6500  115.3333     59.14        79           3
# 1      Honggang  46.4667  124.8667     -4.45        87          11
# 2      Cidreira -30.1811  -50.2056     71.98        94          96
# 3     Jamestown  42.0970  -79.2353     31.59        89         100
# 4       Rikitea -23.1203 -134.9692     74.70        76         100
# 5  Punta Arenas -53.1500  -70.9167     57.31        47          75
# 6       Paredon  16.0333  -93.8667     84.65        60          20
# 7        Broome  42.2506  -75.8330     33.62        67          75
# 8         Airai  -8.9266  125.4092     65.70        63          27
# 9          Taft  31.7471   54.2088     46.35        43          20
#
#    Wind Speed Country
# 0        5.30      AU
# 1        9.10      CN
# 2       15.95      BR
# 3        5.75      US
# 4        9.91      PF
# 5       28.77      CL
# 6       20.69      MX
# 7       11.50      US
# 8        1.32      TL
# 9        6.91      IR

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]]

# Recreate the DataFrame by using the new column order


# Display sample data
new_column_order
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Busselton      AU -33.6500  115.3333     59.14        79           3
# 1     Honggang      CN  46.4667  124.8667     -4.45        87          11
# 2     Cidreira      BR -30.1811  -50.2056     71.98        94          96
# 3    Jamestown      US  42.0970  -79.2353     31.59        89         100
# 4      Rikitea      PF -23.1203 -134.9692     74.70        76         100
# ..         ...     ...      ...       ...       ...       ...         ...
# 701   Vokhtoga      RU  58.8147   41.0461      6.73        96          90
# 702     Teshie      GH   5.5836   -0.1072     80.56        78          85
# 703  Hiranagar      IN  32.4500   75.2667     59.86        39         100
# 704     Palana      RU  59.1167  159.9667     10.13        88          81
# 705   Illescas      ES  40.1221   -3.8470     45.79        58           0
#
#      Wind Speed
# 0          5.30
# 1          9.10
# 2         15.95
# 3          5.75
# 4          9.91
# ..          ...
# 701        2.51
# 702        7.83
# 703        1.36
# 704       11.59
# 705        8.95
#
# [706 rows x 8 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
new_column_order.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
new_column_order.to_csv(output_data_file, index_label = "City_ID")
